# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path= ("/content/drive/MyDrive/Skin_tone")

# %%
import sys
sys.path.append('/content/drive/MyDrive/Skin_tone')

# %%
from skin_detection import skin_detection
from skin_tone import skin_tone
from skin_tone_knn import skin_tone_knn
import numpy as np

# %%
image_dir = "/content/drive/MyDrive/Skin_tone/public/test images/brendon_urie_3.jpeg"
mean_color_values = skin_detection(image_dir)

# %%
skin_tone_result = skin_tone(mean_color_values)
skin_tone_knn_result = skin_tone_knn(mean_color_values)

print("Skin Tone (Cosine Similarity):", skin_tone_result)
print("Skin Tone (KNN):", skin_tone_knn_result)
# Out:
# Skin Tone (Cosine Similarity): 4.0
# Skin Tone (KNN): 4
